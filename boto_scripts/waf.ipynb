# %% [markdown]
# ##### [Hands-on: Deploy AWS WAF on ALB and setup WAF Rules](https://www.youtube.com/watch?v=Bj6fDT4oyCE)

# %% [markdown]
# ##### [Hands-on: AWS WAF Integration with CloudFront + Security Dashboard](https://www.youtube.com/watch?v=bHPNRc2APEc)

# %% [markdown]
# ##### [AWS WAF Made Simple: Protect Your Web Apps In The Cloud | Full Tutorial](https://www.youtube.com/watch?v=aDW2NDUBAOw&t=8s)

# %% [markdown]
# ##### [How to use AWS WAF/Web ACL? - Step By Step Tutorial (Part-11)](https://www.youtube.com/watch?v=FHRXXrQ765M&t=238s)

# %% [markdown]
# ##### [Traditional Web Hosting on AWS: Robust Security with Amazon CloudFront, AWS WAF & Secrets Manager](https://www.youtube.com/watch?v=ujBARGA3224&t=1951s)
#
# -   [Traditional Web Hosting on AWS](https://awstip.com/traditional-web-hosting-on-aws-part-3-building-robust-security-with-amazon-cloudfront-aws-waf-74b2f60bcc94)
